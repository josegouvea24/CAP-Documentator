# %%
import os
import tempfile
import git
from pathlib import Path, PosixPath
from collections import defaultdict

IGNORED_DIRS = {"node_modules", ".git", ".vscode", "_i18n", "dist"}
IGNORED_FILES = {".gitignore", "package-lock.json", ".env"}

def clone_repo(repo_url):
    temp_dir = tempfile.mkdtemp()
    git.Repo.clone_from(repo_url, temp_dir)
    return temp_dir

def classify_files(repo_path):
    repo_path = Path(repo_path)
    files_by_category = defaultdict(lambda: defaultdict(list))
    all_files = []

    for root, dirs, files in os.walk(repo_path):
        # Filter out ignored directories
        dirs[:] = [d for d in dirs if d not in IGNORED_DIRS]
        
        for file in files:
            # Filter out ignored files
            if file in IGNORED_FILES:
                continue
            
            path = Path(root) / file
            rel_path = path.relative_to(repo_path)
            all_files.append(rel_path)

            # Group by top-level folder (CAP convention)
            parts = rel_path.parts
            category = parts[0] if len(parts) > 1 else "root"
            files_by_category[category][path.suffix.lower()].append(rel_path)

    return dict(files_by_category)

# %%
temp_dir = clone_repo("https://github.tools.sap/Delivery-Scale-PT/opportunity-assistant-CAP")
files_by_type = classify_files(temp_dir)
files_by_type
# Out:
# {'root': defaultdict(list,
#              {'': [PosixPath('core'), PosixPath('.eslintrc')],
#               '.md': [PosixPath('README.md')],
#               '.json': [PosixPath('xs-security.json'),
#                PosixPath('package.json')],
#               '.yaml': [PosixPath('mta.yaml')]}),
#  'app': defaultdict(list,
#              {'.cds': [PosixPath('app/services.cds'),
#                PosixPath('app/opportunityassistantcockpit/annotations.cds')],
#               '.yaml': [PosixPath('app/opportunityassistantcockpit/ui5-deploy.yaml'),
#                PosixPath('app/opportunityassistantcockpit/ui5.yaml')],
#               '.md': [PosixPath('app/opportunityassistantcockpit/README.md')],
#               '.json': [PosixPath('app/opportunityassistantcockpit/package.json'),
#                PosixPath('app/opportunityassistantcockpit/xs-app.json'),
#                PosixPath('app/opportunityassistantcockpit/webapp/manifest.json'),
#                PosixPath('app/opportunityassistantcockpit/webapp/model/sideContent.json')],
#               '.html': [PosixPath('app/opportunityassistantcockpit/webapp/index.html'),
#                PosixPath('app/opportunityassistantcockpit/webapp/test/unit/unitTests.qunit.html'),
#                PosixPath('app/opportunityassistantcockpit/webapp/test/integration/opaTests.qunit.html')],
#               '.js': [PosixPath('app/opportunityassistantcockpit/webapp/Component.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/test/unit/AllTests.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/test/unit/unitTests.qunit.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/test/unit/model/formatter.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/test/unit/model/models.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/test/integration/AllJourneys.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/test/integration/NavigationJourney.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/test/integration/opaTests.qunit.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/test/integration/arrangements/Startup.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/test/integration/pages/Home.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/test/integration/pages/Statistics.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/test/integration/pages/App.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/test/integration/pages/Settings.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/util/ServiceUtil.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/controller/Settings.controller.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/controller/App.controller.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/controller/Logs.controller.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/controller/Files.controller.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/controller/Prompts.controller.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/controller/BaseController.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/controller/Sources.controller.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/controller/Home.controller.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/controller/Assistant.controller.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/model/formatter.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/model/models.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/lib/opencv.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/lib/tfjs.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/lib/axios.min.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/control/D3ComparisonChart.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/control/D3PieChart.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/control/D3ColumnChart.js'),
#                PosixPath('app/opportunityassistantcockpit/webapp/control/D3Chart.js')],
#               '.jpg': [PosixPath('app/opportunityassistantcockpit/webapp/reuse/appvar1/images/sports/header_sports_small.jpg'),
#                PosixPath('app/opportunityassistantcockpit/webapp/reuse/appvar1/images/sports/header_sports.jpg'),
#                PosixPath('app/opportunityassistantcockpit/webapp/reuse/appvar1/images/travel/header_travel.jpg'),
#                PosixPath('app/opportunityassistantcockpit/webapp/reuse/appvar1/images/travel/header_travel_small.jpg'),
#                PosixPath('app/opportunityassistantcockpit/webapp/reuse/appvar2/images/travel/header_travel.jpg'),
#                PosixPath('app/opportunityassistantcockpit/webapp/reuse/appvar2/images/travel/header_travel_small.jpg')],
#               '.properties': [PosixPath('app/opportunityassistantcockpit/webapp/reuse/appvar1/i18n/i18n_de.properties'),
#                PosixPath('app/opportunityassistantcockpit/webapp/reuse/appvar1/i18n/i18n_en.properties'),
#                PosixPath('app/opportunityassistantcockpit/webapp/reuse/appvar1/i18n/terminologies/sports/i18n.terminologies.sports_en.properties'),
#                PosixPath('app/opportunityassistantcockpit/webapp/reuse/appvar1/i18n/terminologies/sports/i18n.terminologies.sports_de.properties'),
#                PosixPath('app/opportunityassistantcockpit/webapp/reuse/appvar1/i18n/terminologies/travel/i18n.terminologies.travel_de.properties'),
#                PosixPath('app/opportunityassistantcockpit/webapp/reuse/appvar1/i18n/terminologies/travel/i18n.terminologies.travel_en.properties'),
#                PosixPath('app/opportunityassistantcockpit/webapp/reuse/appvar2/i18n/i18n_de.properties'),
#                PosixPath('app/opportunityassistantcockpit/webapp/reuse/appvar2/i18n/i18n_en.properties'),
#                PosixPath('app/opportunityassistantcockpit/webapp/reuse/appvar2/i18n/terminologies/travel/i18n.terminologies.travel_de.properties'),
#                PosixPath('app/opportunityassistantcockpit/webapp/reuse/appvar2/i18n/terminologies/travel/i18n.terminologies.travel_en.properties'),
#                PosixPath('app/opportunityassistantcockpit/webapp/i18n/i18n_en.properties'),
#                PosixPath('app/opportunityassistantcockpit/webapp/i18n/i18n.properties'),
#                PosixPath('app/opportunityassistantcockpit/webapp/i18n/terminologies/sports/i18n.terminologies.sports_en.properties'),
#                PosixPath('app/opportunityassistantcockpit/webapp/i18n/terminologies/sports/i18n.terminologies.sports_de.properties'),
#                PosixPath('app/opportunityassistantcockpit/webapp/i18n/terminologies/travel/i18n.terminologies.travel_de.properties'),
#                PosixPath('app/opportunityassistantcockpit/webapp/i18n/terminologies/travel/i18n.terminologies.travel_en.properties')],
#               '.css': [PosixPath('app/opportunityassistantcockpit/webapp/css/style.css')],
#               '.xml': [PosixPath('app/opportunityassistantcockpit/webapp/view/CreatePromptDialog.fragment.xml'),
#                PosixPath('app/opportunityassistantcockpit/webapp/view/FeedbackDialog.fragment.xml'),
#                PosixPath('app/opportunityassistantcockpit/webapp/view/Settings.view.xml'),
#                PosixPath('app/opportunityassistantcockpit/webapp/view/Home.view.xml'),
#                PosixPath('app/opportunityassistantcockpit/webapp/view/App.view.xml'),
#                PosixPath('app/opportunityassistantcockpit/webapp/view/Logs.view.xml'),
#                PosixPath('app/opportunityassistantcockpit/webapp/view/ConfirmDeletionDialog.fragment.xml'),
#                PosixPath('app/opportunityassistantcockpit/webapp/view/Prompts.view.xml'),
#                PosixPath('app/opportunityassistantcockpit/webapp/view/Sources.view.xml'),
#                PosixPath('app/opportunityassistantcockpit/webapp/view/Files.view.xml'),
#                PosixPath('app/opportunityassistantcockpit/webapp/view/Assistant.view.xml')]}),
#  'db': defaultdict(list,
#              {'.cds': [PosixPath('db/schema.cds')],
#               '.json': [PosixPath('db/undeploy.json')],
#               '.csv': [PosixPath('db/data/opportunityassistant-ChatPrompt.csv')],
#               '': [PosixPath('db/src/.hdiconfig')]}),
#  'srv': defaultdict(list,
#              {'.cds': [PosixPath('srv/api.cds')],
#               '.js': [PosixPath('srv/server.js'),
#                PosixPath('srv/AICoreUtilChatbot.js'),
#                PosixPath('srv/CFUtil.js'),
#                PosixPath('srv/bucketUtil.js'),
#                PosixPath('srv/AICoreUtil.js'),
#                PosixPath('srv/api.js'),
#                PosixPath('srv/util/AxiosUtil.js'),
#                PosixPath('srv/util/DataServiceUtil.js'),
#                PosixPath('srv/util/sharepoint.js')]})}

# %%
files_by_type = { 'srv': defaultdict(list,
             {'.cds': [PosixPath('srv/api.cds')],
              '.js': [PosixPath('srv/server.js'),
               PosixPath('srv/AICoreUtilChatbot.js'),
               PosixPath('srv/CFUtil.js'),
               PosixPath('srv/bucketUtil.js'),
               PosixPath('srv/AICoreUtil.js'),
               PosixPath('srv/api.js'),
               PosixPath('srv/util/AxiosUtil.js'),
               PosixPath('srv/util/DataServiceUtil.js'),
               PosixPath('srv/util/sharepoint.js')]})}
files_by_type
# Out:
# {'srv': defaultdict(list,
#              {'.cds': [PosixPath('srv/api.cds')],
#               '.js': [PosixPath('srv/server.js'),
#                PosixPath('srv/AICoreUtilChatbot.js'),
#                PosixPath('srv/CFUtil.js'),
#                PosixPath('srv/bucketUtil.js'),
#                PosixPath('srv/AICoreUtil.js'),
#                PosixPath('srv/api.js'),
#                PosixPath('srv/util/AxiosUtil.js'),
#                PosixPath('srv/util/DataServiceUtil.js'),
#                PosixPath('srv/util/sharepoint.js')]})}

# %%
from dataclasses import dataclass, field

@dataclass
class DocChunk:
    name: str             # logical name or file base name
    path: str             # relative path in the repo
    section: str          # "root", "srv", "db", etc.
    type: str             # "cds", "js", "xml", etc.
    content: str          # raw file content
    metadata: dict = field(default_factory=dict) # additional metadata

# %%
from pathlib import Path

def chunk_files(repo_path: Path, files_by_section: dict) -> list[DocChunk]:
    """
    Chunk files into a list of DocChunks objects with metadata.
    
    Args:
        repo_path (Path): The path to the repository.
        files_by_section (dict): A dictionary containing files grouped by section and then type.
        
    Returns:
        list: A list of DocChunks objects representing the chunked files.
    """
    chunks = []

    for section, files in files_by_section.items():
        for file_type, file_paths in files.items():
            for file_path in file_paths:
                full_path = repo_path / file_path
                try:
                    with open(full_path, 'r', encoding='utf-8') as f:
                        content = f.read()
  
                    chunk = DocChunk(
                        name=file_path.stem,
                        path=str(file_path),
                        section=section,
                        type=file_type,
                        content=content,
                        metadata={}
                    )
                    chunks.append(chunk)
                
                except Exception as e:
                    print(f"❌ Failed to read {file_path}: {e}")

    return chunks

# %%
chunks = chunk_files(Path(temp_dir), files_by_type)
chunks
# Out:
# [DocChunk(name='api', path='srv/api.cds', section='srv', type='.cds', content="using opportunityassistant as db from '../db/schema';\n\nservice APIService @(requires: [\n    'authenticated-user',\n    'Viewer'\n]) {\n    /*-- DB Entities --*/\n    @restrict: [\n        {\n            grant: 'READ',\n            to   : 'Viewer'\n        },\n        {\n            grant: '*',\n            to   : 'Admin'\n        }\n    ]\n    entity ChatPrompt   as projection on db.ChatPrompt;\n\n    @restrict: [\n        {\n            grant: 'WRITE',\n            to   : 'Viewer'\n        },\n        {\n            grant: '*',\n            to   : 'Admin'\n        }\n    ]\n    entity ChatFeedback as projection on db.ChatFeedback;\n\n    function userInfo()                                                                  returns String;\n\n    @requires: 'Admin'\n    function getAdminOptions()                                                           returns String;\n\n    @requires: 'Admin'\n    action   setAdminOptions(defaultApprover : String);\n\n    /*Function Imports*/\n    action   chatMemory(query : String)                                                  returns String;\n    action   chatHistoryByUserId()                                                       returns String;\n    function isChatbotEnabled()                                                          returns Boolean;\n    function getSharepointConnectUrl()                                                   returns String;\n    function getAzureToken()                                                             returns String;\n    function getBidCases(top : Integer, skip : Integer)                                  returns array of String;\n\n    @requires: 'Admin'\n    function getBidCasesWithDeliverables(top : Integer, skip : Integer, caseId : String) returns String;\n\n    function getStats()                                                                  returns String;\n    function isAzureTokenValid()                                                         returns String;\n    function getFilesByCaseId(caseId : String)                                           returns String;\n    function getAllFiles()                                                               returns String;\n    function searchFilesByExternalIdOrFileName(search : String)                          returns String;\n\n    /*Actions*/\n    @requires: 'Admin'\n    action   deleteFilesByCaseId(caseId : String)                                        returns String;\n\n    @requires: 'Admin'\n    action   deleteDocumentsAndFiles()                                                   returns String;\n\n    action   refreshChat(model : String)                                                 returns String;\n\n    @requires: 'Admin'\n    function loadBidCaseDeliverablesToVectorDB(caseId : String)                          returns String;\n\n    @requires: 'Admin'\n    function loadAllBidCaseDeliverablesToVectorDB()                                      returns String;\n\n    @requires: 'Admin'\n    function restartLoadAllBidCaseDeliverablesToVectorDB()                               returns String;\n\n    @requires: 'Admin'\n    function getBidCaseLoadStatuses()                                                    returns String;\n\n    @requires: 'Admin'\n    action   getLogs(search : String)                                                    returns String;\n\n    @requires: 'Admin'\n    action   createLog(executionId : String, message : String)                           returns String;\n}\n", metadata={}),
#  DocChunk(name='server', path='srv/server.js', section='srv', type='.js', content='"use strict";\n\nconst cds = require("@sap/cds");\nconst proxy = require("@sap/cds-odata-v2-adapter-proxy");\nconst { WebSocketServer } = require("ws");\nconst { parse } = require("url");\n\n// WebSocket library\n//const wss = new WebSocketServer({ port: 8080 });\nconst wss = new WebSocketServer({ noServer: true });\n\nwss.on("connection", (ws) => {\n  console.log("New client connected");\n\n  emitMessageToClients(\'Ping all Clients\');\n\n  ws.on("message", (message) => {\n    console.log("Received message:", message.toString());\n    // Handle incoming WebSocket messages here.\n  });\n\n  ws.on("close", () => {\n    console.log("Client disconnected");\n  });\n});\n\nconst emitMessageToClients = (message) => {\n  wss.clients.forEach((client) => {\n    if (client.readyState === 1) {\n      client.send(JSON.stringify(message));\n    }\n  });\n}\n\ncds.on("listening", ({ server }) => {\n  console.log("--> listening");\n\n  server.on("upgrade", (request, socket, head) => {\n    const { pathname } = parse(request.url);\n    if (pathname === "/ws" || pathname === "/index.html/ws") {\n/*       authenticate(request, function next(err, client) {\n        if (err) {\n          socket.write("HTTP/1.1 401 Unauthorized\\r\\n\\r\\n");\n          socket.destroy();\n          return;\n        } */\n        wss.handleUpgrade(request, socket, head, (ws) => {\n          console.log("WSS HandleUpgrade");\n          wss.emit("connection", ws, request);\n       // });\n      });\n    } else {\n      console.warn(`Pathname ${pathname} not allowed for WebSocket connection`);\n      socket.destroy();\n    }\n  });\n\n  global.wss = wss;\n\n});\n\ncds.on("bootstrap", (app) => app.use(proxy()));\n\nmodule.exports = cds.server;\n', metadata={}),
#  DocChunk(name='AICoreUtilChatbot', path='srv/AICoreUtilChatbot.js', section='srv', type='.js', content="/* eslint-disable consistent-return */\nconst axios = require('axios');\n\nconst CONTENT_TYPE_JSON = 'application/json';\n\nconst getToken = async () => {\n  const credentials = `${process.env.AICORE_CLIENT_ID}:${process.env.AICORE_CLIENT_SECRET}`;\n  const encodedCredentials = Buffer.from(credentials).toString('base64');\n  const config = {\n    method: 'get',\n    maxBodyLength: Infinity,\n    url: `${process.env.AICORE_AUTH_URL}/oauth/token?grant_type=client_credentials`,\n    headers: {\n      Authorization: `Basic ${encodedCredentials}`\n    }\n  };\n\n  const authResponse = await axios.request(config);\n  return authResponse.data.access_token;\n};\n\nconst chat = async sQuestion => {\n  const sToken = await getToken();\n\n  const data = JSON.stringify({\n    query: sQuestion\n  });\n\n  const config = {\n    method: 'post',\n    maxBodyLength: Infinity,\n    url: `${process.env.AICORE_DEPLOYMENT_URL}/v1/chat`,\n    headers: {\n      'AI-Resource-Group': 'default',\n      'Content-Type': CONTENT_TYPE_JSON,\n      Authorization: `Bearer ${sToken}`\n    },\n    data\n  };\n\n  const resp = await axios.request(config);\n  return resp.data;\n};\n\nconst chatWithMemory = async (sQuestion, sUserId) => {\n  const sToken = await getToken();\n\n  const data = JSON.stringify({\n    query: sQuestion,\n    user_id: sUserId\n  });\n\n  const config = {\n    method: 'post',\n    maxBodyLength: Infinity,\n    url: `${process.env.AICORE_DEPLOYMENT_URL}/v1/chat-memory`,\n    headers: {\n      'AI-Resource-Group': 'default',\n      'Content-Type': CONTENT_TYPE_JSON,\n      Authorization: `Bearer ${sToken}`\n    },\n    data\n  };\n\n  const resp = await axios.request(config);\n  return resp.data;\n};\n\nconst getStatus = async () => {\n  const sToken = await getToken();\n\n  const config = {\n    method: 'get',\n    url: `${process.env.AICORE_DEPLOYMENT_URL}/v1/status`,\n    headers: {\n      'AI-Resource-Group': 'default',\n      Authorization: `Bearer ${sToken}`\n    }\n  };\n\n  const resp = await axios.request(config);\n  return resp.data;\n};\n\nconst getRefresh = async () => {\n  const sToken = await getToken();\n\n  const config = {\n    method: 'get',\n    url: `${process.env.AICORE_DEPLOYMENT_URL}/v1/refresh`,\n    headers: {\n      'AI-Resource-Group': 'default',\n      Authorization: `Bearer ${sToken}`\n    }\n  };\n\n  const resp = await axios.request(config);\n  return resp.data;\n};\n\nmodule.exports = {\n  getToken, chat, getStatus, getRefresh, chatWithMemory\n};\n", metadata={}),
#  DocChunk(name='CFUtil', path='srv/CFUtil.js', section='srv', type='.js', content='/* eslint-disable consistent-return */\nconst { getDestination } = require(\'@sap-cloud-sdk/core\');\nconst axios = require(\'axios\');\n\nconst sDestinationCF = \'CF_API\';\nconst sDestinationCFLogin = \'CF_LOGIN\';\n\nconst sEMAIL = process.env.EMAIL_SENDER || \'test@emea.adsint.biz\';\n\nconst getTokenCF = async () => {\n  // const oDestination = await getDestination("CF_API");\n  const oDestination = await getDestination(sDestinationCFLogin);\n  const qs = require(\'qs\');\n\n  const data = qs.stringify({\n    username: oDestination.username,\n    password: oDestination.password\n  });\n  const config = {\n    method: \'post\',\n    url: `${ oDestination.url }/oauth/token?grant_type=password`,\n    headers: {\n      \'Authorization\': \'Basic Y2Y6\',\n      \'Content-Type\': \'application/x-www-form-urlencoded\'\n    },\n    data\n  };\n\n  try {\n    const res = await axios(config);\n\n    return res.data.access_token;\n  } catch (error) {\n    console.log(error);\n  }\n};\n\nconst sendEmail = async (sEmail, sContent) => {\n  const sToken = await getMSGraphToken();\n  const data = JSON.stringify({\n    message: {\n      subject: \'Entity training logs\',\n      body: {\n        contentType: \'Text\',\n        content: `Details: \\n\\n ${ sContent }`\n      },\n      toRecipients: [\n        {\n          emailAddress: {\n            address: sEmail\n          }\n        }\n      ],\n      ccRecipients: [\n        {\n          emailAddress: {\n            address: \'test@xxxx.com\'\n          }\n        }\n      ]\n    },\n    saveToSentItems: \'false\'\n  });\n\n  const config = {\n    method: \'post\',\n    url: `https://graph.microsoft.com/v1.0/users(\'${ sEMAIL }\')/sendMail`,\n    headers: {\n      \'Authorization\': `Bearer ${ sToken }`,\n      \'Content-Type\': \'application/json\'\n    },\n    data\n  };\n\n  try {\n    await axios(config);\n  } catch (error) {\n    console.log();\n  }\n};\n\nconst getMSGraphToken = async () => {\n  const oDestination = await getDestination(\'MICROSOFT_GRAPH_API\');\n\n  return oDestination.authTokens[0].value;\n};\n\nmodule.exports = { getTokenCF, getMSGraphToken, sendEmail };\n', metadata={}),
#  DocChunk(name='bucketUtil', path='srv/bucketUtil.js', section='srv', type='.js', content='const AWS = require("aws-sdk");\n\n// Configure AWS with your credentials and S3 bucket details\nAWS.config.update({\n  accessKeyId: process.env.ACCESS_KEY_ID,\n  secretAccessKey: process.env.SECRET_ACCESS_KEY,\n  region: process.env.REGION,\n});\n\nconst s3 = new AWS.S3();\n\nasync function deleteBucket(bucketName) {\n  try {\n    // List all objects in the bucket\n    const objects = await s3.listObjectsV2({ Bucket: bucketName }).promise();\n\n    // Delete all objects in the bucket\n    if (objects.Contents.length > 0) {\n      const deleteParams = {\n        Bucket: bucketName,\n        Delete: { Objects: objects.Contents.map((obj) => ({ Key: obj.Key })) },\n      };\n\n      await s3.deleteObjects(deleteParams).promise();\n      console.log("All objects in the bucket deleted successfully.");\n    }\n\n    // Delete the bucket itself\n    await s3.deleteBucket({ Bucket: bucketName }).promise();\n    console.log("Bucket deleted successfully.");\n  } catch (error) {\n    console.error("Error deleting bucket:", error.message);\n    throw error;\n  }\n}\nasync function listBuckets() {\n  try {\n    const data = await s3.listBuckets().promise();\n    const bucketNames = data.Buckets.map((bucket) => bucket.Name);\n    console.log("Buckets in your account:", bucketNames);\n    return bucketNames;\n  } catch (error) {\n    console.error("Error listing buckets:", error.message);\n    throw error;\n  }\n}\n\nasync function getObjectContentByKey(sKey){\n  const content = await s3\n  .getObject({ Bucket: process.env.BUCKET, Key: sKey })\n  .promise();\n\n  return content.Body.toString("base64");\n\n}\n\nasync function listAllMyObjects() {\n  const params = {\n    Bucket: process.env.BUCKET,\n    Prefix: `ai/orangecircle/`\n  };\n\n  return await s3.listObjectsV2(params).promise();\n}\n\nasync function listAllObjects() {\n  const params = {\n    Bucket: process.env.BUCKET\n  };\n\n  return await s3.listObjectsV2(params).promise();\n}\n\nasync function listObjectsWithBase64Content(\n  bucketName,\n  metadataKey,\n  metadataValue\n) {\n  const params = {\n    Bucket: bucketName,\n    Prefix: `ai/orangecircle/images/${metadataValue}/`\n  };\n\n  try {\n    const data = await s3.listObjectsV2(params).promise();\n\n    // Get content in base64 for each object\n    const objectsWithContent = await Promise.all(\n      data.Contents.map(async (object) => {\n        const content = await s3\n          .getObject({ Bucket: bucketName, Key: object.Key })\n          .promise();\n        if (content.Metadata[metadataKey] === metadataValue) {\n          return {\n            ...object,\n            ContentBase64: content.Body.toString("base64"),\n          };\n        }\n        return null;\n      })\n    );\n\n    // Filter out objects without matching metadata\n    const filteredObjects = objectsWithContent.filter(\n      (object) => object !== null\n    );\n\n    console.log("Objects with Base64 Content:", filteredObjects);\n    return { result: filteredObjects };\n  } catch (error) {\n    console.error("Error listing objects with base64 content:", error.message);\n    throw error;\n  }\n}\n\nasync function bucketExists(bucketName) {\n  try {\n    await s3.headBucket({ Bucket: bucketName }).promise();\n    return true;\n  } catch (error) {\n    if (error.code === "NotFound") {\n      return false;\n    } else {\n      return false;\n    }\n  }\n}\n\nasync function listObjects(bucketName) {\n  const params = {\n    Bucket: bucketName,\n  };\n\n  try {\n    const data = await s3.listObjectsV2(params).promise();\n    const files = data.Contents.map((object) => object.Key);\n    console.log("Files in the bucket:", files);\n    return files;\n  } catch (error) {\n    console.error("Error listing objects:", error.message);\n    throw error;\n  }\n}\n\nasync function listObjects(bucketName) {\n  const params = {\n    Bucket: bucketName,\n  };\n\n  try {\n    cons ...
#  DocChunk(name='AICoreUtil', path='srv/AICoreUtil.js', section='srv', type='.js', content='/* eslint-disable consistent-return */\nconst axios = require(\'axios\');\n\n\nconst getToken = async () => {\n\n  const credentials = `${process.env.AICORE_CLIENT_ID}:${process.env.AICORE_CLIENT_SECRET}`;\n  const encodedCredentials = Buffer.from(credentials).toString(\'base64\');\n  const config = {\n    method: \'get\',\n    maxBodyLength: Infinity,\n    url: `${process.env.AICORE_URL}/oauth/token?grant_type=client_credentials`,\n    headers: { \n      \'Authorization\': `Basic ${encodedCredentials}`\n    }\n  };\n  \n  const authResponse = await axios.request(config);\n  return authResponse.data.access_token;\n};\n\nconst getStatus = async(token) =>{\n\n  let sToken;\n  if(!token){\n    sToken = await getToken();\n  } \n  \n\n  let config = {\n    method: \'get\',\n    maxBodyLength: Infinity,\n    url: `${process.env.AICORE_DEPLOYMENT_URL}/v1/status`,\n    headers: { \n      \'AI-Resource-Group\': \'default\', \n      \'Content-Type\': \'application/json\', \n      \'Authorization\': `Bearer ${sToken}`\n    }\n  };\n  const resp = await axios.request(config);\n  return resp.data;\n}\n\nconst getModelStatus = async(req, token) =>{\n\n  const { entity } = req.data;\n\n  let sToken;\n  if(!token){\n    sToken = await getToken();\n  } \n  \n\n  let config = {\n    method: \'get\',\n    maxBodyLength: Infinity,\n    url: `${process.env.AICORE_DEPLOYMENT_URL}/v1/check-model-status/${entity}`,\n    headers: { \n      \'AI-Resource-Group\': \'default\', \n      \'Content-Type\': \'application/json\', \n      \'Authorization\': `Bearer ${sToken}`\n    }\n  };\n  \n  const resp = await axios.request(config);\n  return resp.data;\n}\n\nconst createExecution = async () => {\n\n  const sToken = await getToken();\n\n\n  let data = JSON.stringify({\n    "configurationId": process.env.AICORE_CONFIGURATION_ID\n  });\n  \n  let config = {\n    method: \'post\',\n    maxBodyLength: Infinity,\n    url: `${process.env.AICORE_API_URL}/v2/lm/executions`,\n    headers: { \n      \'AI-Resource-Group\': \'default\', \n      \'Content-Type\': \'application/json\', \n      \'Authorization\': `Bearer ${sToken}`\n    },\n    data : data\n  };\n  \n  const resp = await axios.request(config);\n  return resp.data;\n\n}\n\nconst predict = async (req, token) => {\n\n  const { content, entity, percentile } = req.data;\n\n  let sToken;\n  if(!token){\n    sToken = await getToken();\n  } \n\n  let data = JSON.stringify({\n    \'entity\': entity,\n    \'percentile\': percentile,\n    \'content\': content\n  });\n  \n  let config = {\n    method: \'post\',\n    maxBodyLength: Infinity,\n    url: `${process.env.AICORE_DEPLOYMENT_URL}/v1/predict`,\n    headers: { \n      \'AI-Resource-Group\': \'default\', \n      \'Content-Type\': \'application/json\', \n      \'Authorization\': `Bearer ${sToken}`\n    },\n    data : data\n  };\n  \n  const resp = await axios.request(config);\n  return resp.data;\n\n}\n\nconst refreshModelServer = async () => {\n\n  const sToken = await getToken();\n  \n  let config = {\n    method: \'get\',\n    maxBodyLength: Infinity,\n    url: `${process.env.AICORE_DEPLOYMENT_URL}/v1/refresh`,\n    headers: { \n      \'AI-Resource-Group\': \'default\', \n      \'Content-Type\': \'application/json\', \n      \'Authorization\': `Bearer ${sToken}`\n    }\n  };\n  \n  const resp = await axios.request(config);\n  return resp.data;\n\n}\n\nmodule.exports = { getToken, getModelStatus, getStatus, predict, createExecution, refreshModelServer };\n', metadata={}),
#  DocChunk(name='api', path='srv/api.js', section='srv', type='.js', content='const cds = require("@sap/cds");\nconst ShortUniqueId = require("short-unique-id");\nconst { TextBundle } = require("@sap/textbundle");\nconst axios = require("axios");\nconst LOG = cds.log("assistant-srv");\nconst dataServiceUtil = require("./util/DataServiceUtil");\nconst AxiosUtil = require("./util/AxiosUtil");\n/* const WebSocketServer = require("ws").Server;\nconst ws = new WebSocketServer({\n  port: process.env.PORT || 8080,\n}); */\n\nconst tokenStore = {};\nconst ingestLocks = {};\n\nconst {\n  getSharepointConnectUrl,\n  connectSharepoint,\n} = require("./util/sharepoint");\n\nmodule.exports = async (srv) => {\n  const { AdminPreference } = srv.entities;\n\n  //const AICoreUtilChatbot = require("./AICoreUtilChatbot");\n\n  /**\n   * To get the specific props from the context\n   * @param {*} context\n   * @returns\n   */\n  function getContext(context) {\n    const ctxHost = context?.req?.get("host");\n    const protocol = ["localhost"].some((host) => ctxHost.includes(host))\n      ? "http"\n      : "https";\n    const ctx = {\n      user: {\n        id: context?.user?.id,\n      },\n      req: {\n        protocol,\n        get: (key = "host") => ctxHost,\n        hostname: context?.headers?.host,\n        query: context?.req?.query,\n        param: context?.req?.param,\n      },\n      data: context?.data || null,\n    };\n    return ctx;\n  }\n\n  srv.on("getBidCases", async (req) => {\n    try {\n      const { top, skip } = req.data;\n      const bidCases = await dataServiceUtil.getBidCases(top, skip);\n      return bidCases;\n    } catch (error) {\n      req.error(400, "Failed to fetch bid cases");\n    }\n  });\n\n  srv.on("getBidCasesWithDeliverables", async (req) => {\n    try {\n      const { top, skip, caseId } = req.data;\n      const bidCases = await dataServiceUtil.getBidCasesWithDeliverables(\n        top,\n        skip,\n        caseId\n      );\n\n      // get files for each bid case\n      const getFiles = [];\n      for (let i = 0; i < bidCases.length; i++) {\n        const caseId = bidCases[i].CASEID;\n        getFiles.push(dataServiceUtil.getFilesByCaseId(caseId));\n      }\n      // wait for all files to be fetched\n      const files = await Promise.all(getFiles);\n      // add files to bid cases and check if case is being ingested\n      for (let i = 0; i < bidCases.length; i++) {\n        bidCases[i].files = files[i];\n        bidCases[i].filesCount = files[i].length;\n        bidCases[i].isIngesting = checkLock(bidCases[i].CASEID);\n      }\n\n      return { results: bidCases };\n    } catch (error) {\n      req.error(400, "Failed to fetch bid cases and deliverables");\n    }\n  });\n\n  srv.on("loadBidCaseDeliverablesToVectorDB", async (req) => {\n    const { caseId } = req.data;\n    try {\n      addLock(caseId);\n      const loadingResults =\n        await dataServiceUtil.loadBidCaseDeliverablesToVectorDB(\n          caseId,\n          tokenStore[req.user.id]\n        );\n      dropLock(caseId);\n      return loadingResults;\n    } catch (error) {\n      dropLock(caseId);\n      req.reject(400, "Failed to fetch bid cases and deliverables");\n    }\n  });\n\n  srv.on("getBidCaseLoadStatuses", async (req) => {\n    try {\n      const statuses = await dataServiceUtil.getBidCaseLoadStatuses();\n      return statuses;\n    } catch (error) {\n      req.error(400, "Failed to fetch bid case load statuses");\n    }\n  });\n\n  srv.on("deleteDocumentsAndFiles", async (req) => {\n    try {\n      const deleteResults = await dataServiceUtil.deleteDocumentsAndFiles();\n      return deleteResults;\n    } catch (error) {\n      req.reject(400, "Failed deleting documents and files from vector DB");\n    }\n  });\n\n  srv.on("loadAllBidCaseDeliverablesToVectorDB", async (req) => {\n    try {\n      dataServiceUtil.loadAllBidCaseDeliverablesToVectorDB(tokenStore[req.user.id]);\n      return "Loading started";\n    } catch (error) {\n  ...
#  DocChunk(name='AxiosUtil', path='srv/util/AxiosUtil.js', section='srv', type='.js', content='const axios = require("axios");\nconst jwtDecode = require("jwt-decode"); // You\'ll need to install this library: npm install jwt-decode\n\nclass AxiosUtil {\n  constructor(baseURL = "", defaultHeaders = {}, tokenConfig = {}) {\n    this.apiClient = axios.create({\n      baseURL,\n      headers: defaultHeaders,\n    });\n\n    this.token = null;\n    this.tokenConfig = {\n      tokenEndpoint: tokenConfig.tokenEndpoint || "generate-token",\n      credentials: tokenConfig.credentials || {},\n    };\n\n    // Attach the token to every request if available\n    this.apiClient.interceptors.request.use(async (config) => {\n      await this.ensureToken();\n      if (this.token) {\n        config.headers.Authorization = `Bearer ${this.token}`;\n      }\n      return config;\n    });\n\n    // Request interceptor\n    this.apiClient.interceptors.request.use(\n      (config) => {\n        console.log("Request Interceptor:", {\n          url: config.url,\n          method: config.method,\n          headers: config.headers,\n          data: config.data,\n          params: config.params,\n        });\n        return config;\n      },\n      (error) => {\n        console.error("Request Error Interceptor:", error);\n        return Promise.reject(error);\n      }\n    );\n  }\n\n  async ensureToken() {\n    if (!this.token || this.isTokenExpired()) {\n      await this.refreshToken();\n    }\n  }\n\n  isTokenExpired() {\n    if (!this.token) return true;\n    try {\n      const decodedToken = jwtDecode.jwtDecode(this.token);\n      const currentTime = Math.floor(Date.now() / 1000); // in seconds\n      return currentTime >= decodedToken.exp; // Check if the token is expired\n    } catch (error) {\n      console.error("Failed to decode token:", error.message);\n      return true; // Treat as expired if decoding fails\n    }\n  }\n\n  static checkTokenExpired(sToken) {\n    if (!sToken) return true;\n    try {\n      const decodedToken = jwtDecode.jwtDecode(sToken);\n      const currentTime = Math.floor(Date.now() / 1000); // in seconds\n      return currentTime >= decodedToken.exp; // Check if the token is expired\n    } catch (error) {\n      console.error("Failed to decode token:", error.message);\n      return true; // Treat as expired if decoding fails\n    }\n  }\n\n  async refreshToken() {\n    try {\n      // Encode client_id and client_secret in Base64\n      const { client_id, client_secret } = this.tokenConfig.credentials;\n      const authHeader = `Basic ${Buffer.from(\n        `${client_id}:${client_secret}`\n      ).toString("base64")}`;\n\n      const response = await axios.post(\n        this.tokenConfig.tokenEndpoint,\n        {}, // Assuming the body is empty for token requests with Basic Auth\n        {\n          headers: {\n            Authorization: authHeader,\n            "Content-Type": "application/json", // Set appropriate content type\n          },\n        }\n      );\n\n      // Save the token from the response\n      this.token = response.data.access_token; // Assuming the token is in the `access_token` field\n    } catch (error) {\n      console.error("Failed to refresh token:", error.message);\n      throw error;\n    }\n  }\n\n  async get(endpoint, params = {}, headers = {}) {\n    try {\n      const response = await this.apiClient.get(endpoint, {\n        params,\n        headers: {\n          ...this.apiClient.defaults.headers.common, // Include default headers\n          ...headers, // Merge with headers passed to the method\n        },\n      });\n      return response.data;\n    } catch (error) {\n      this.handleError(error);\n    }\n  }\n\n  async post(endpoint, data = {}, headers = {}) {\n    try {\n      const response = await this.apiClient.post(endpoint, data, {\n        headers,\n      });\n      return response.data;\n    } catch (error) {\n      this.handleError(error);\n    }\n  }\n\n  async put(endpoin ...
#  DocChunk(name='DataServiceUtil', path='srv/util/DataServiceUtil.js', section='srv', type='.js', content='const { use } = require("passport");\nconst AxiosUtil = require("./AxiosUtil");\n\nclass DataServiceUtil {\n  constructor(baseURL, tokenConfig) {\n    // Initialize AxiosUtil with the provided base URL and token configuration\n    this.apiClient = new AxiosUtil(baseURL, {}, tokenConfig);\n  }\n\n  async getBidCases(top, skip) {\n    try {\n      // Define query parameters as an object\n      const params = {\n        $top: top,\n        $skip: skip,\n        $select:\n          "CASEID,OPPID,CASENAME,DESCRIPTION,CUSTOMER,CUSTOMERID,MARKETUNIT,SCSTARTDATE,SCSTATUS,CRMCLOSEQUARTER,CRMOWNERNAME,TOP900CUSTUMER,OPPVALUE,OPPVALUECUR,INDUSTRY,CRMCOUNTRY",\n      };\n\n      const items = await this.apiClient.get("/list-bid-cases", params);\n      return items;\n    } catch (error) {\n      console.error("Error fetching bid cases:", error.message);\n      throw error; // Rethrow the error for the calling code to handle\n    }\n  }\n\n  async chatMemory(query, userId) {\n    try {\n      const items = await this.apiClient.post(`/chat-memory`, {\n        query,\n        user_id: userId,\n      });\n      return items;\n    } catch (error) {\n      console.error("Error fetching chat with memory:", error.message);\n      throw error;\n    }\n  }\n\n  async chatHistoryByUserId(userId) {\n    try {\n      const items = await this.apiClient.post(`/chat-history-memory`, {\n        user_id: userId,\n      });\n      return items;\n    } catch (error) {\n      console.error("Error fetching chat history by user ID:", error.message);\n      throw error;\n    }\n  }\n\n  async loadBidCaseDeliverablesToVectorDB(caseId, azureToken) {\n    try {\n      const items = await this.apiClient.get(\n        `/load-bid-case-deliverables-by-id/${caseId}`,\n        null,\n        { "azure-token": azureToken }\n      );\n      return items;\n    } catch (error) {\n      console.error(\n        "Error loading bid case deliverables to vector DB:",\n        error.message\n      );\n      throw error;\n    }\n  }\n\n  async deleteDocumentsAndFiles(){\n    try {\n      const items = await this.apiClient.delete(`/delete-documents-and-files`);\n      return items;\n    } catch (error) {\n      console.error(\n        "Error deleting documents and files from vector DB:",\n        error.message\n      );\n      throw error;\n    }\n  }\n\n  async getBidCaseLoadStatuses() {\n    try {\n      const result = await this.apiClient.get(`/bid-case-load-statuses`);\n      return result;\n    } catch (error) {\n      console.error("Error fetching bid case load statuses:", error.message);\n      throw error;\n    }\n  }\n\n  async loadAllBidCaseDeliverablesToVectorDB(azureToken) {\n    try {\n      const items = await this.apiClient.get(\n        `load-all-bid-cases-deliverables`,\n        null,\n        { "azure-token": azureToken }\n      );\n      return items;\n    } catch (error) {\n      console.error(\n        "Error loading ALL bid case deliverables to vector DB:",\n        error.message\n      );\n      throw error;\n    }\n  }\n\n  async restartLoadAllBidCaseDeliverablesToVectorDB() {\n    try {\n      const items = await this.apiClient.get(\n        `restart-load-all-bid-cases-deliverables`,\n        null\n      );\n      return items;\n    } catch (error) {\n      console.error(\n        "Error restarting loading ALL bid case deliverables to vector DB:",\n        error.message\n      );\n      throw error;\n    }\n  }\n\n  async searchFilesByExternalIdOrFileName(searchParam) {\n    try {\n      const items = await this.apiClient.get(\n        `/search-files-by-external-id-or-file-name/${searchParam || ""}`,\n        null\n      );\n      return items;\n    } catch (error) {\n      console.error(\n        "Error searching files by external ID or file name:",\n        error.message\n      );\n      throw error;\n    }\n  }\n\n  async getFilesByExternalId(externalId) ...
#  DocChunk(name='sharepoint', path='srv/util/sharepoint.js', section='srv', type='.js', content='const msal = require(\'@azure/msal-node\');\nconst { ConfidentialClientApplication } = require(\'@azure/msal-node\');\n\nconst cryptoProvider = new msal.CryptoProvider();\n\n\nfunction getSharepointConfig(context) {\n    const msalConfig = {\n        auth: {\n            clientId: process.env.CLIENT_ID, // \'Application (client) ID\' of app registration in Azure portal - this value is a GUID\n            authority: process.env.AUTHORITY, // Full directory URL, in the form of https://login.microsoftonline.com/<tenant>\n            clientSecret: process.env.CLIENT_SECRET // Client secret generated from the app registration in Azure portal\n        },\n        system: {\n            loggerOptions: {\n                loggerCallback(loglevel, message, containsPii) {\n                    // console.log(message);\n                },\n                piiLoggingEnabled: false,\n                logLevel: "Info",\n            }\n        }\n    }\n    // const baseUrl = OathTokenService.getBaseUrl(context);\n    const REDIRECT_URI = process.env.REDIRECT_URI; // Ensure Callback URL with AppRouter Host is provided in env variables\n    const REDIRECT_LOGOUT_PATH = process.env.REDIRECT_LOGOUT_PATH;\n    const GRAPH_ME_ENDPOINT = process.env.GRAPH_BASE_URL + "/me";\n    return {\n        msalConfig,\n        REDIRECT_URI,\n        REDIRECT_LOGOUT_PATH,\n        GRAPH_ME_ENDPOINT\n    }\n}\n\nasync function connectSharepoint({ code }, context, redirecUrl) {\n    const user = context.user.id;\n    if (!code || !user) { return }\n    const { REDIRECT_URI, msalConfig } = getSharepointConfig(context)\n    const redirectUri = redirecUrl || REDIRECT_URI;\n    const msalInstance = new msal.ConfidentialClientApplication(msalConfig);\n    try {\n        const data = await msalInstance.acquireTokenByCode({ code, redirectUri: redirectUri });\n        return data;//await _saveToken(msalInstance, data, user);\n    } catch (error) {\n        console.error(error)\n    }\n}\n\nasync function getSharepointConnectUrl(context, redirecUrl) {\n    const { REDIRECT_URI, msalConfig } = getSharepointConfig(context)\n    const msalInstance = new msal.ConfidentialClientApplication(msalConfig);\n    const redirectUri = redirecUrl || REDIRECT_URI;\n    cds.log(`Redirect URI: ${redirectUri}`)\n    const state = cryptoProvider.base64Encode(\n        JSON.stringify({\n            // csrfToken: cryptoProvider.createNewGuid(),\n            redirectTo: \'/\'\n        })\n    );\n    const authCodeUrlRequestParams = {\n        state: state,\n\n        /**\n         * By default, MSAL Node will add OIDC scopes to the auth code url request. For more information, visit:\n         * https://docs.microsoft.com/azure/active-directory/develop/v2-permissions-and-consent#openid-connect-scopes\n         */\n        scopes: ["User.ReadBasic.All", "Files.ReadWrite.All","Sites.Read.All"],\n        responseMode: \'query\',\n        redirectUri: redirectUri\n    };\n    try {\n        const url = await msalInstance.getAuthCodeUrl(authCodeUrlRequestParams);\n        return url\n    } catch (error) {\n        console.error(error)\n    }\n\n}\n\nmodule.exports = { getSharepointConfig, getSharepointConnectUrl, connectSharepoint };', metadata={})]

# %%
def get_summary_prompt(chunk):
    name = chunk.name
    ext = chunk.type.lstrip(".")
    section = chunk.section
    path = chunk.path

    return f"""You are a documentation assistant working as part of a multi-layered AI system designed to automate the generation of technical documentation for SAP CAP (Cloud Application Programming Model) projects.

            **Context and Purpose**
            Your output will serve as an intermediate representation to help a second LLM construct comprehensive documentation for the entire CAP system. This includes API references, architecture diagrams, service guides, user manuals, and other artifacts. The final documentation must be understandable by both developers and non-technical stakeholders (e.g., project managers, clients, business analysts).

            **Your Task**
            Carefully analyze the code chunk below and produce a clear, structured description that will help the second LLM reason about the CAP system as a whole. Focus on:

            - Accurately referencing all identifiers (functions, entities, views, annotations, etc.)
            - Prioritizing CAP-specific concepts and logic (e.g., services, entities, event handlers, annotations, configurations)
            - Avoiding speculation: do **not** infer behavior or relationships that are not explicitly present in the file

            **Output Requirements**
            - Use plain, unformatted text
            - Use clear technical language
            - Describe; do not summarize
            - If the file appears incomplete, test-related, or unclear, state that honestly

            ---

            **File Details**
            - Name: {name}
            - Type: {ext}
            - Section: {section}
            - Path: {path}

            ---

            **File Content**
            {chunk.content[:4000]}

            ---
            """

# %%
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

from gen_ai_hub.proxy.native.openai import chat

def call_llm(prompt: str, model: str = "gpt-4o", temperature: float = 0) -> str:
    """
    Calls LLM with a given prompt through AI Core and returns the response.
    
    Args:
        prompt (str): The user prompt.
        model (str): LLM model name (e.g., "gpt-4o").
    
    Returns:
        str: The LLM-generated response.
    """
    
    try:
        response = chat.completions.create(
                        model=model,
                        temperature=temperature,
                        messages=[
                            {"role": "system", "content": "You are a documentation assistant."},
                            {"role": "user", "content": prompt}
                        ]
                    )
    
        return response.choices[0].message.content
    
    except Exception as e:
        print(f"❌ LLM call failed: {e}")
        return "[ERROR: failed to get LLM response]"

# %%
for chunk in chunks:
    prompt = get_summary_prompt(chunk)
    
    # Call the LLM with the prompt
    response = call_llm(prompt)
    
    # Print the LLM response
    print(f"LLM Response for {chunk.name}:\n{response}\n")
# Out:
# LLM Response for api:
# The file `srv/api.cds` defines a service named `APIService` within the SAP Cloud Application Programming Model (CAP). This service is designed to interact with entities and functions related to a database schema named `opportunityassistant`, which is imported from the path `../db/schema`.
#
# ### Service Definition
#
# - **Service Name**: `APIService`
# - **Annotations**:
#   - `@requires`: Specifies access control requirements for the service, indicating that users must be authenticated and have the 'Viewer' role to access the service.
#
# ### Entities
#
# The service defines two entities as projections on database entities:
#
# 1. **Entity `ChatPrompt`**:
#    - Projection on `db.ChatPrompt`.
#    - Access Control:
#      - `READ` access granted to 'Viewer'.
#      - Full access (`*`) granted to 'Admin'.
#
# 2. **Entity `ChatFeedback`**:
#    - Projection on `db.ChatFeedback`.
#    - Access Control:
#      - `WRITE` access granted to 'Viewer'.
#      - Full access (`*`) granted to 'Admin'.
#
# ### Functions and Actions
#
# The service includes several functions and actions, some of which have specific access requirements:
#
# - **Functions**:
#   - `userInfo()`: Returns a `String`.
#   - `getAdminOptions()`: Returns a `String`. Requires 'Admin' role.
#   - `isChatbotEnabled()`: Returns a `Boolean`.
#   - `getSharepointConnectUrl()`: Returns a `String`.
#   - `getAzureToken()`: Returns a `String`.
#   - `getBidCases(top: Integer, skip: Integer)`: Returns an array of `String`.
#   - `getBidCasesWithDeliverables(top: Integer, skip: Integer, caseId: String)`: Returns a `String`. Requires 'Admin' role.
#   - `getStats()`: Returns a `String`.
#   - `isAzureTokenValid()`: Returns a `String`.
#   - `getFilesByCaseId(caseId: String)`: Returns a `String`.
#   - `getAllFiles()`: Returns a `String`.
#   - `searchFilesByExternalIdOrFileName(search: String)`: Returns a `String`.
#   - `loadBidCaseDeliverablesToVectorDB(caseId: String)`: Returns a `String`. Requires 'Admin' role.
#   - `loadAllBidCaseDeliverablesToVectorDB()`: Returns a `String`. Requires 'Admin' role.
#   - `restartLoadAllBidCaseDeliverablesToVectorDB()`: Returns a `String`. Requires 'Admin' role.
#   - `getBidCaseLoadStatuses()`: Returns a `String`. Requires 'Admin' role.
#
# - **Actions**:
#   - `setAdminOptions(defaultApprover: String)`: Requires 'Admin' role.
#   - `chatMemory(query: String)`: Returns a `String`.
#   - `chatHistoryByUserId()`: Returns a `String`.
#   - `deleteFilesByCaseId(caseId: String)`: Returns a `String`. Requires 'Admin' role.
#   - `deleteDocumentsAndFiles()`: Returns a `String`. Requires 'Admin' role.
#   - `refreshChat(model: String)`: Returns a `String`.
#   - `getLogs(search: String)`: Returns a `String`. Requires 'Admin' role.
#   - `createLog(executionId: String, message: String)`: Returns a `String`. Requires 'Admin' role.
#
# ### Access Control
#
# The service employs access control annotations to restrict certain functions and actions to users with the 'Admin' role, ensuring that sensitive operations are protected and only accessible to authorized personnel.
#
# ### Observations
#
# The file appears complete and provides a structured definition of the `APIService` with clear access control mechanisms and a variety of functions and actions that interact with the database entities. The service is designed to handle operations related to chat prompts, feedback, bid cases, and file management, with specific functions for administrative tasks.
#
# LLM Response for server:
# The provided JavaScript file, located at `srv/server.js`, is part of the SAP CAP (Cloud Application Programming Model) project and serves as a server configuration script. It utilizes the SAP Cloud SDK (`@sap/cds`) and integrates WebSocket functionality to handle real-time communication with clients. Below is a detailed description of the file's components and logic:
#
# 1. **Imports and Dependencies**:
#    - The script imports the `@sap/cds` module, which is central to the CAP framework, providing essential functionalities for service and data model management.
#    - It imports the `@sap/cds-odata-v2-adapter-proxy`, which is used to enable OData V2 protocol support, allowing for backward compatibility with older OData services.
#    - The `ws` module is imported to create a WebSocket server, facilitating real-time, bidirectional communication between the server and clients.
#    - The `url` module is imported for parsing URLs, which is used in handling WebSocket upgrade requests.
#
# 2. **WebSocket Server Configuration**:
#    - A `WebSocketServer` instance is created with the `noServer` option, indicating that it will not listen on its own but will be integrated with an existing HTTP server.
#    - The WebSocket server (`wss`) listens for `connection` events, where it logs the connection and sets up handlers for incoming messages and client disconnections.
#
# 3. **WebSocket Message Handling**:
#    - The `emitMessageToClients` function broadcasts messages to all connected WebSocket clients whose `readyState` is open (value `1`), ensuring that only active connections receive messages.
#
# 4. **CDS Event Handlers**:
#    - The script sets up an event listener for the `listening` event emitted by the CDS server. This event signifies that the server is ready to accept connections.
#    - Within the `listening` event handler, the server listens for `upgrade` requests, which are necessary for establishing WebSocket connections. It checks the request's pathname to determine if it should handle the WebSocket upgrade. If the pathname matches `/ws` or `/index.html/ws`, it proceeds with the WebSocket upgrade process.
#    - The `handleUpgrade` method of the WebSocket server is used to complete the WebSocket handshake, allowing the connection to be established.
#
# 5. **Global WebSocket Server Reference**:
#    - The WebSocket server instance (`wss`) is assigned to the global scope, making it accessible throughout the application.
#
# 6. **CDS Bootstrap Event**:
#    - The script listens for the `bootstrap` event, during which it applies the OData V2 adapter proxy middleware to the application (`app`). This middleware integration is crucial for enabling OData V2 support.
#
# 7. **Module Export**:
#    - The script exports the CDS server instance, making it available for use in other parts of the application.
#
# Overall, the file is focused on integrating WebSocket capabilities into the SAP CAP server, allowing for real-time communication with clients while maintaining compatibility with OData V2 services. The use of event handlers and middleware demonstrates typical CAP practices for extending server functionality.
#
# LLM Response for AICoreUtilChatbot:
# The file `AICoreUtilChatbot.js` is a JavaScript module located in the `srv` section of an SAP CAP project. It appears to be responsible for interacting with an AI Core service, specifically handling authentication and various API requests related to chatbot functionalities. The module utilizes the `axios` library to perform HTTP requests.
#
# ### Identifiers and Functions
#
# 1. **Constants:**
#    - `CONTENT_TYPE_JSON`: A string constant set to `'application/json'`, used to specify the content type in HTTP headers.
#
# 2. **Functions:**
#    - `getToken`: An asynchronous function that retrieves an access token using client credentials. It constructs a request to an OAuth token endpoint, using environment variables `AICORE_CLIENT_ID`, `AICORE_CLIENT_SECRET`, and `AICORE_AUTH_URL`. The function returns the access token from the response data.
#
#    - `chat`: An asynchronous function that sends a chat query to the AI Core service. It first obtains an access token via `getToken`, then sends a POST request to the endpoint specified by `AICORE_DEPLOYMENT_URL` with the path `/v1/chat`. The request includes the query in JSON format and uses the access token for authorization.
#
#    - `chatWithMemory`: Similar to `chat`, this function sends a chat query along with a user ID to the AI Core service. It targets the `/v1/chat-memory` endpoint, allowing the service to maintain context or memory of the conversation.
#
#    - `getStatus`: An asynchronous function that retrieves the status of the AI Core deployment. It sends a GET request to the `/v1/status` endpoint, using an access token for authorization.
#
#    - `getRefresh`: An asynchronous function that sends a GET request to the `/v1/refresh` endpoint to refresh or update the AI Core deployment status, using an access token for authorization.
#
# ### Module Exports
#
# The module exports the following functions: `getToken`, `chat`, `getStatus`, `getRefresh`, and `chatWithMemory`. These functions are intended to be used by other parts of the CAP system to interact with the AI Core service.
#
# ### CAP-Specific Concepts
#
# - **Environment Variables**: The module relies on several environment variables (`AICORE_CLIENT_ID`, `AICORE_CLIENT_SECRET`, `AICORE_AUTH_URL`, `AICORE_DEPLOYMENT_URL`) to configure API requests. This is a common practice in CAP projects to manage configuration and credentials securely.
#
# - **Service Interaction**: The functions in this module facilitate interaction with external services, which is a typical pattern in CAP projects where services are defined to encapsulate business logic and external integrations.
#
# ### Observations
#
# - The file is complete and provides a clear implementation of service functions for interacting with an AI Core chatbot.
# - The use of `axios` for HTTP requests and the handling of authentication tokens are standard practices for service integration in CAP projects.
# - The module does not define any CAP-specific entities, views, or annotations, focusing solely on service logic for API communication.
#
# LLM Response for CFUtil:
# The file `CFUtil.js` located in the `srv` directory is a JavaScript module that provides utility functions for interacting with external services, specifically for obtaining tokens and sending emails. The file utilizes the SAP Cloud SDK and the Axios library to perform HTTP requests.
#
# ### Identifiers and Functions
#
# 1. **Constants:**
#    - `sDestinationCF`: A string constant set to `'CF_API'`, presumably used to identify a destination related to Cloud Foundry API.
#    - `sDestinationCFLogin`: A string constant set to `'CF_LOGIN'`, used to identify a destination for Cloud Foundry login.
#    - `sEMAIL`: A constant that retrieves the email sender address from the environment variable `EMAIL_SENDER`, defaulting to `'test@emea.adsint.biz'` if not set.
#
# 2. **Functions:**
#    - `getTokenCF`: An asynchronous function that retrieves an access token from a Cloud Foundry login service. It uses the `getDestination` function from the SAP Cloud SDK to obtain destination details, including username and password, and constructs a POST request to obtain an OAuth token. The function returns the access token if successful, or logs an error if the request fails.
#    - `sendEmail`: An asynchronous function that sends an email using Microsoft Graph API. It first retrieves an access token using the `getMSGraphToken` function, then constructs a POST request to send an email with specified content and recipients. The function logs an error if the request fails.
#    - `getMSGraphToken`: An asynchronous function that retrieves an authentication token for Microsoft Graph API. It uses the `getDestination` function to obtain the token from the destination identified by `'MICROSOFT_GRAPH_API'`.
#
# ### CAP-Specific Concepts
#
# - **Destinations:** The file makes use of the `getDestination` function from the SAP Cloud SDK to interact with external services. Destinations are a key concept in SAP CAP, allowing applications to connect to remote services securely.
# - **Environment Variables:** The use of environment variables (`EMAIL_SENDER`) for configuration is a common practice in CAP applications to manage settings and credentials.
#
# ### Observations
#
# - The file appears to be complete and focused on utility functions for token retrieval and email sending.
# - The code does not include any CAP-specific entities, services, or event handlers directly, but it leverages the SAP Cloud SDK for destination management, which is relevant in CAP projects.
# - The file does not contain any annotations or configurations specific to CAP entities or services.
#
# This description provides a structured overview of the `CFUtil.js` file, highlighting its role in token management and email communication within the context of a CAP project.
#
# LLM Response for bucketUtil:
# The file `bucketUtil.js` is a JavaScript module located in the `srv` section of an SAP CAP project. It primarily deals with operations related to AWS S3 buckets, utilizing the AWS SDK for JavaScript. The module includes several asynchronous functions that perform various tasks on S3 buckets and objects. Below is a detailed description of the functions and their roles:
#
# 1. **AWS Configuration**:
#    - The AWS SDK is imported and configured using credentials and region information sourced from environment variables (`ACCESS_KEY_ID`, `SECRET_ACCESS_KEY`, `REGION`). This setup is essential for authenticating and interacting with AWS services.
#
# 2. **S3 Instance**:
#    - An instance of the AWS S3 service is created (`const s3 = new AWS.S3();`) to facilitate bucket and object operations.
#
# 3. **Function `deleteBucket(bucketName)`**:
#    - This function deletes all objects within a specified bucket and then deletes the bucket itself.
#    - It first lists all objects in the bucket using `s3.listObjectsV2`.
#    - If objects are present, it constructs a delete request and deletes them using `s3.deleteObjects`.
#    - Finally, it deletes the bucket using `s3.deleteBucket`.
#
# 4. **Function `listBuckets()`**:
#    - Lists all buckets in the AWS account.
#    - It retrieves bucket information using `s3.listBuckets` and returns an array of bucket names.
#
# 5. **Function `getObjectContentByKey(sKey)`**:
#    - Fetches the content of an object specified by a key from a bucket defined in the environment variable `BUCKET`.
#    - The content is returned as a base64-encoded string.
#
# 6. **Function `listAllMyObjects()`**:
#    - Lists objects in a bucket with a specific prefix (`ai/orangecircle/`).
#    - The bucket is specified by the environment variable `BUCKET`.
#
# 7. **Function `listAllObjects()`**:
#    - Lists all objects in a bucket specified by the environment variable `BUCKET`.
#
# 8. **Function `listObjectsWithBase64Content(bucketName, metadataKey, metadataValue)`**:
#    - Lists objects in a specified bucket with a prefix and filters them based on metadata.
#    - Retrieves the content of each object in base64 format if the object's metadata matches the provided key and value.
#
# 9. **Function `bucketExists(bucketName)`**:
#    - Checks if a bucket exists by attempting to retrieve its metadata using `s3.headBucket`.
#    - Returns `true` if the bucket exists, otherwise `false`.
#
# 10. **Function `listObjects(bucketName)`**:
#     - Lists all objects in a specified bucket.
#     - Returns an array of object keys.
#
# The file appears to be complete and provides utility functions for managing AWS S3 buckets and objects. It does not contain CAP-specific entities, services, or annotations, focusing instead on AWS operations.
#
# LLM Response for AICoreUtil:
# The file `AICoreUtil.js` is a JavaScript module located in the `srv` section of an SAP CAP project. It provides utility functions for interacting with an AI Core service, primarily through HTTP requests using the `axios` library. The module exports several asynchronous functions, each designed to perform specific operations related to authentication and interaction with the AI Core service.
#
# 1. **getToken**: This function retrieves an access token using client credentials. It constructs a basic authentication header with encoded credentials derived from environment variables `AICORE_CLIENT_ID` and `AICORE_CLIENT_SECRET`. The function sends a GET request to the OAuth token endpoint specified by `AICORE_URL` and returns the access token from the response.
#
# 2. **getStatus**: This function checks the status of the AI Core deployment. It optionally accepts a token; if not provided, it calls `getToken` to obtain one. It sends a GET request to the status endpoint specified by `AICORE_DEPLOYMENT_URL`, using the token in the Authorization header, and returns the status data.
#
# 3. **getModelStatus**: This function checks the status of a specific model. It requires a request object containing an `entity` identifier and optionally a token. If the token is not provided, it calls `getToken`. It sends a GET request to the model status endpoint, appending the `entity` to the URL, and returns the model status data.
#
# 4. **createExecution**: This function initiates a new execution in the AI Core service. It first retrieves a token using `getToken`. It constructs a POST request with a JSON payload containing a `configurationId` from the environment variable `AICORE_CONFIGURATION_ID`. The request is sent to the executions endpoint specified by `AICORE_API_URL`, and the function returns the execution data.
#
# 5. **predict**: This function performs a prediction operation. It requires a request object containing `content`, `entity`, and `percentile`, and optionally a token. If the token is not provided, it calls `getToken`. It constructs a POST request with a JSON payload containing the prediction parameters and sends it to the predict endpoint, returning the prediction result.
#
# 6. **refreshModelServer**: This function refreshes the model server. It retrieves a token using `getToken` and sends a GET request to the refresh endpoint specified by `AICORE_DEPLOYMENT_URL`. The function returns the response data from the server refresh operation.
#
# The module exports all these functions, making them available for use in other parts of the CAP project. Each function is designed to interact with specific endpoints of the AI Core service, utilizing environment variables for configuration and authentication.
#
# LLM Response for api:
# The JavaScript file `api.js` located in the `srv` directory is part of an SAP CAP (Cloud Application Programming Model) project. It defines several asynchronous event handlers for a service, utilizing various utilities and external libraries to perform operations related to bid cases and deliverables. Below is a detailed description of the file's contents:
#
# 1. **Imports and Dependencies**:
#    - The file imports the `@sap/cds` module, which is central to SAP CAP projects, providing functionalities for service definitions and event handling.
#    - It uses `short-unique-id` for generating unique identifiers, `@sap/textbundle` for handling text bundles, and `axios` for making HTTP requests.
#    - A logging utility is initialized with `cds.log("assistant-srv")`.
#    - Several utility modules are imported: `DataServiceUtil` and `AxiosUtil`, which likely contain helper functions for data operations and HTTP requests, respectively.
#    - The file also imports functions from `./util/sharepoint`, specifically `getSharepointConnectUrl` and `connectSharepoint`, indicating integration with SharePoint services.
#
# 2. **Global Variables**:
#    - `tokenStore` and `ingestLocks` are defined as empty objects. These are likely used to store user tokens and manage locks for data ingestion processes.
#
# 3. **Service Definition**:
#    - The module exports an asynchronous function that receives a service (`srv`) as an argument. Within this function, the `AdminPreference` entity is accessed from `srv.entities`, suggesting that this entity is part of the service's data model.
#
# 4. **Utility Function**:
#    - `getContext(context)`: This function extracts specific properties from the provided `context` object, such as user ID, request protocol, host, query parameters, and request data. It determines the protocol based on the host name, defaulting to "http" for localhost and "https" otherwise.
#
# 5. **Event Handlers**:
#    - `srv.on("getBidCases", async (req) => {...})`: Handles requests to fetch bid cases, utilizing `dataServiceUtil.getBidCases` with pagination parameters `top` and `skip`.
#    - `srv.on("getBidCasesWithDeliverables", async (req) => {...})`: Fetches bid cases along with their deliverables, using `dataServiceUtil.getBidCasesWithDeliverables`. It also retrieves associated files for each bid case and checks if the case is being ingested.
#    - `srv.on("loadBidCaseDeliverablesToVectorDB", async (req) => {...})`: Loads deliverables of a specific bid case into a vector database, managing locks with `addLock` and `dropLock` functions.
#    - `srv.on("getBidCaseLoadStatuses", async (req) => {...})`: Retrieves the load statuses of bid cases using `dataServiceUtil.getBidCaseLoadStatuses`.
#    - `srv.on("deleteDocumentsAndFiles", async (req) => {...})`: Deletes documents and files from a vector database, calling `dataServiceUtil.deleteDocumentsAndFiles`.
#    - `srv.on("loadAllBidCaseDeliverablesToVectorDB", async (req) => {...})`: Initiates loading of all bid case deliverables into a vector database.
#    - `srv.on("restartLoadAllBidCaseDeliverablesToVectorDB", async (req) => {...})`: Intended to restart the loading process for all bid case deliverables, but the implementation appears incomplete.
#
# 6. **Incomplete Code**:
#    - The file ends abruptly with an incomplete function `srv.on("restartLoadAllBidCa`, indicating that the code is not fully implemented or the file is incomplete.
#
# Overall, the file is focused on handling bid case data and interactions with a vector database, utilizing various utilities for data management and external service integration. The presence of incomplete code suggests that further development or correction is needed.
#
# LLM Response for AxiosUtil:
# The provided JavaScript file, `AxiosUtil.js`, is located in the `srv/util` directory and appears to be a utility module designed to facilitate HTTP requests using the Axios library. It includes functionality for handling authentication tokens, specifically JWT (JSON Web Tokens), to ensure secure API interactions. Below is a detailed description of the file's components:
#
# ### Class: AxiosUtil
#
# - **Constructor**:
#   - Initializes an Axios client (`apiClient`) with a specified `baseURL` and `defaultHeaders`.
#   - Sets up token management with a `tokenConfig` object, which includes a `tokenEndpoint` and `credentials` (client ID and secret).
#   - Configures request interceptors to attach an authorization token to each request if available.
#
# - **Token Management**:
#   - **ensureToken()**: Ensures a valid token is available before making requests. If the token is expired or not present, it calls `refreshToken()`.
#   - **isTokenExpired()**: Checks if the current token is expired by decoding it using `jwtDecode` and comparing the expiration time (`exp`) with the current time.
#   - **static checkTokenExpired(sToken)**: A static method to check if a given token (`sToken`) is expired, similar to `isTokenExpired()`.
#   - **refreshToken()**: Requests a new token from the `tokenEndpoint` using Basic Authentication with encoded client credentials. The new token is stored in the `token` property.
#
# - **HTTP Methods**:
#   - **get(endpoint, params, headers)**: Performs a GET request to the specified `endpoint` with optional query `params` and additional `headers`. It merges these headers with the default headers.
#   - **post(endpoint, data, headers)**: Executes a POST request to the `endpoint` with provided `data` and `headers`.
#   - **put(endpoint, data, headers)**: Sends a PUT request to the `endpoint` with specified `data` and `headers`.
#
# - **Interceptors**:
#   - **Request Interceptor**: Logs request details (URL, method, headers, data, params) before the request is sent. It also handles errors by logging them and rejecting the promise.
#
# ### External Dependencies
#
# - **axios**: A promise-based HTTP client for the browser and Node.js, used to create and manage HTTP requests.
# - **jwt-decode**: A library for decoding JWT tokens, used to verify token expiration.
#
# ### Error Handling
#
# - **handleError(error)**: Although not fully visible in the provided content, this method is likely responsible for managing errors that occur during HTTP requests.
#
# ### Observations
#
# - The file is focused on managing HTTP requests and authentication tokens, which are common tasks in service layers of applications.
# - The use of interceptors and token management suggests an emphasis on security and logging, which are critical in enterprise applications.
# - The file appears to be complete in terms of its primary functionality, though the `handleError` method is not fully visible, indicating potential incompleteness in error management.
#
# This description provides a comprehensive view of the `AxiosUtil.js` file, highlighting its role in handling HTTP requests and token-based authentication within the SAP CAP framework.
#
# LLM Response for DataServiceUtil:
# The file `DataServiceUtil.js` is a JavaScript module located in the `srv/util` directory, which appears to be part of a service layer in an SAP CAP project. This module defines a class named `DataServiceUtil` that provides utility functions for interacting with external services using HTTP requests. The class utilizes an `AxiosUtil` instance to perform these requests, which is initialized with a `baseURL` and `tokenConfig` provided during the construction of a `DataServiceUtil` object.
#
# ### Class: DataServiceUtil
#
# - **Constructor**:
#   - Initializes an `AxiosUtil` instance (`this.apiClient`) with the given `baseURL` and `tokenConfig`. This setup is crucial for making authenticated HTTP requests to external services.
#
# ### Methods
#
# 1. **getBidCases(top, skip)**:
#    - Performs a GET request to the `/list-bid-cases` endpoint.
#    - Accepts `top` and `skip` parameters to define pagination and constructs query parameters including `$select` to specify fields to be retrieved.
#    - Returns a list of bid cases.
#
# 2. **chatMemory(query, userId)**:
#    - Executes a POST request to the `/chat-memory` endpoint.
#    - Sends a payload containing `query` and `user_id`.
#    - Returns chat memory items associated with the user.
#
# 3. **chatHistoryByUserId(userId)**:
#    - Executes a POST request to the `/chat-history-memory` endpoint.
#    - Sends a payload with `user_id`.
#    - Returns chat history for the specified user.
#
# 4. **loadBidCaseDeliverablesToVectorDB(caseId, azureToken)**:
#    - Performs a GET request to `/load-bid-case-deliverables-by-id/{caseId}`.
#    - Includes an `azure-token` in the request headers for authentication.
#    - Loads bid case deliverables into a vector database.
#
# 5. **deleteDocumentsAndFiles()**:
#    - Executes a DELETE request to `/delete-documents-and-files`.
#    - Deletes documents and files from a vector database.
#
# 6. **getBidCaseLoadStatuses()**:
#    - Performs a GET request to `/bid-case-load-statuses`.
#    - Retrieves the load statuses of bid cases.
#
# 7. **loadAllBidCaseDeliverablesToVectorDB(azureToken)**:
#    - Executes a GET request to `load-all-bid-cases-deliverables`.
#    - Uses an `azure-token` for authentication.
#    - Loads all bid case deliverables into a vector database.
#
# 8. **restartLoadAllBidCaseDeliverablesToVectorDB()**:
#    - Performs a GET request to `restart-load-all-bid-cases-deliverables`.
#    - Restarts the loading process of all bid case deliverables into a vector database.
#
# 9. **searchFilesByExternalIdOrFileName(searchParam)**:
#    - Executes a GET request to `/search-files-by-external-id-or-file-name/{searchParam}`.
#    - Searches for files using an external ID or file name.
#
# 10. **getFilesByExternalId(externalId)**:
#     - Performs a GET request to `/get-files-by-external-id/{externalId}`.
#     - Retrieves files associated with a specific external ID.
#
# ### Observations
#
# - The file is complete and provides a clear set of utility functions for interacting with external services, particularly focusing on bid cases and chat functionalities.
# - The methods are designed to handle errors by logging them and rethrowing for further handling by the calling code.
# - The use of `AxiosUtil` suggests a modular approach to HTTP requests, potentially allowing for easier configuration and extension.
#
# This file does not directly reference CAP-specific concepts such as entities, services, or annotations, but it is likely part of a broader service layer that interacts with CAP entities and services.
#
# LLM Response for sharepoint:
# The JavaScript file `sharepoint.js` located in the `srv/util` directory is designed to facilitate integration with Microsoft SharePoint using the Microsoft Authentication Library (MSAL) for Node.js. This file primarily deals with authentication and connection setup for SharePoint services within the context of SAP CAP projects.
#
# ### Key Components and Functions
#
# 1. **Dependencies and Initialization:**
#    - The file imports the `msal-node` package, specifically utilizing the `ConfidentialClientApplication` class and `CryptoProvider`.
#    - A `cryptoProvider` instance is created from `msal.CryptoProvider`.
#
# 2. **Function: `getSharepointConfig(context)`**
#    - This function constructs and returns a configuration object for MSAL based on environment variables.
#    - **MSAL Configuration (`msalConfig`):**
#      - `auth`: Contains authentication details such as `clientId`, `authority`, and `clientSecret`, all sourced from environment variables.
#      - `system`: Configures logging options, with a callback function for logging and settings for PII logging and log level.
#    - Additional configuration values include `REDIRECT_URI`, `REDIRECT_LOGOUT_PATH`, and `GRAPH_ME_ENDPOINT`, all derived from environment variables.
#
# 3. **Function: `connectSharepoint({ code }, context, redirecUrl)`**
#    - This asynchronous function attempts to acquire an access token using an authorization code.
#    - It checks for the presence of `code` and `user` from the `context`.
#    - Utilizes `getSharepointConfig` to retrieve configuration details and initializes a `ConfidentialClientApplication` instance.
#    - Attempts to acquire a token using `acquireTokenByCode` with the provided authorization code and redirect URI.
#    - Returns the acquired token data or logs an error if the process fails.
#
# 4. **Function: `getSharepointConnectUrl(context, redirecUrl)`**
#    - This asynchronous function generates a URL for SharePoint authentication.
#    - Retrieves configuration details using `getSharepointConfig`.
#    - Constructs a state parameter using `cryptoProvider` to encode a JSON object.
#    - Defines `authCodeUrlRequestParams` with scopes for permissions such as `User.ReadBasic.All`, `Files.ReadWrite.All`, and `Sites.Read.All`.
#    - Attempts to generate an authentication code URL using `getAuthCodeUrl` and returns the URL or logs an error if unsuccessful.
#
# 5. **Exported Functions:**
#    - The module exports three functions: `getSharepointConfig`, `getSharepointConnectUrl`, and `connectSharepoint`.
#
# ### Observations
#
# - The file is focused on handling authentication and connection setup for SharePoint using MSAL, which is crucial for integrating SharePoint services within SAP CAP applications.
# - The use of environment variables for configuration suggests a need for proper setup in deployment environments.
# - The file does not contain any CAP-specific entities, services, or annotations directly, but it provides utility functions that can be used in CAP service implementations to manage SharePoint connectivity.
#
# Overall, this file serves as a utility for managing authentication and connection processes with SharePoint, leveraging Azure's MSAL for secure access and integration.
